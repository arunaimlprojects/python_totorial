# %% [markdown]
# Here are 20 quiz questions related to **Strings in Python**:
#
# ### **Basic Level**
# 1. Which of the following is the correct way to define a string in Python?
#    a) `str = 'Hello'`
#    b) `str = "Hello"`
#    c) `str = '''Hello'''`
#    d) All of the above
#
# 2. What will `len("Python")` return?
#    a) 5
#    b) 6
#    c) 7
#    d) Error
#
# 3. What is the output of `"Hello"[1]`?
#    a) `H`
#    b) `e`
#    c) `l`
#    d) `o`
#
# 4. What will `"Python"[-1]` return?
#    a) `P`
#    b) `y`
#    c) `n`
#    d) `o`
#
# 5. Which method is used to convert a string to lowercase?
#    a) `lower()`
#    b) `toLower()`
#    c) `downcase()`
#    d) `convert_lower()`
#
# 6. Which operator is used for string concatenation?
#    a) `+`
#    b) `*`
#    c) `&`
#    d) `//`
#
# 7. What does `"Python".upper()` return?
#    a) `python`
#    b) `PYTHON`
#    c) `Python`
#    d) Error
#
# 8. What will `"Python"[2:5]` return?
#    a) `tho`
#    b) `yth`
#    c) `tho`
#    d) `ytho`
#
# 9. What will `"Python" * 2` return?
#    a) `PythonPython`
#    b) `Python*2`
#    c) `Error`
#    d) `Python Python`
#
# 10. How can you check if a string starts with a particular substring?
#    a) `startswith()`
#    b) `beginswith()`
#    c) `hasprefix()`
#    d) `start()`
#
# ### **Intermediate Level**
# 11. What will `"Hello".replace("l", "L")` return?
#    a) `HeLLo`
#    b) `Hello`
#    c) `HeLL`
#    d) `HeLLoL`
#
# 12. How do you remove whitespace from both ends of a string?
#    a) `strip()`
#    b) `trim()`
#    c) `cut()`
#    d) `remove()`
#
# 13. What is the output of `"Hello,World".split(",")`?
#    a) `['Hello', 'World']`
#    b) `['Hello', ',World']`
#    c) `['Hello World']`
#    d) `['H', 'e', 'l', 'l', 'o', ',', 'W', 'o', 'r', 'l', 'd']`
#
# 14. Which method is used to check if a string contains only digits?
#    a) `isnumber()`
#    b) `isdigit()`
#    c) `isnumeric()`
#    d) `containsdigits()`
#
# 15. What does `"123".zfill(5)` return?
#    a) `00123`
#    b) `12300`
#    c) `000123`
#    d) `Error`
#
# 16. What will `"Hello".find("l")` return?
#    a) `2`
#    b) `3`
#    c) `4`
#    d) `-1`
#
# 17. What will `"Hello".count("l")` return?
#    a) `1`
#    b) `2`
#    c) `3`
#    d) `4`
#
# 18. What does `"hello".capitalize()` return?
#    a) `Hello`
#    b) `HELLO`
#    c) `hello`
#    d) `error`
#
# 19. How do you check if a string contains only alphabets?
#    a) `isalpha()`
#    b) `isalphabet()`
#    c) `containsalpha()`
#    d) `onlyalpha()`
#
# 20. What does `"-".join(["Python", "is", "fun"])` return?
#    a) `"Python-is-fun"`
#    b) `"Python is fun"`
#    c) `["Python-is-fun"]`
#    d) `Error`
#
# Let me know if you need answers or explanations! 😊
