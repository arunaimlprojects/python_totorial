# %% [markdown]
# quiz

# %% [markdown]
# Here are 25 multiple-choice questions focusing on Python variables, data types, control structures, loops, and the `break` and `continue` statements:
#
# 1. **Which of the following is a mutable data type in Python?**
#    - a) `tuple`
#    - b) `list`
#    - c) `str`
#    - d) `int`
#
# 2. **What will be the output of the following code?**
#    ```python
#    x = 10
#    y = 2
#    print(x ** y)
#    ```
#    - a) `5`
#    - b) `100`
#    - c) `20`
#    - d) `1024`
#
# 3. **Which of the following is not a valid variable name in Python?**
#    - a) `_var`
#    - b) `2var`
#    - c) `var_2`
#    - d) `var2`
#
# 4. **What is the output of the following code?**
#    ```python
#    for i in range(3):
#        print(i)
#    else:
#        print("Done")
#    ```
#    - a) `0 1 2`
#    - b) `0 1 2 Done`
#    - c) `Done`
#    - d) `0 1 Done`
#
# 5. **What does the `break` statement do in a loop?**
#    - a) Skips the current iteration
#    - b) Exits the loop entirely
#    - c) Pauses the loop
#    - d) Restarts the loop
#
# 6. **What will be the output of the following code?**
#    ```python
#    for i in range(5):
#        if i == 3:
#            continue
#        print(i)
#    ```
#    - a) `0 1 2 3 4`
#    - b) `0 1 2 4`
#    - c) `0 1 2`
#    - d) `1 2 4`
#
# 7. **Which of the following is an immutable data type in Python?**
#    - a) `list`
#    - b) `set`
#    - c) `dict`
#    - d) `tuple`
#
# 8. **What is the purpose of the `pass` statement in Python?**
#    - a) To exit a loop
#    - b) To skip the current iteration
#    - c) To do nothing; it's a placeholder
#    - d) To raise an exception
#
# 9. **What will be the output of the following code?**
#    ```python
#    x = 5
#    while x > 0:
#        x -= 1
#        if x == 2:
#            break
#        print(x)
#    ```
#    - a) `4 3 2 1 0`
#    - b) `4 3`
#    - c) `4 3 2`
#    - d) `4 3 1 0`
#
# 10. **Which keyword is used to define a function in Python?**
#     - a) `func`
#     - b) `def`
#     - c) `function`
#     - d) `define`
#
# 11. **What will be the output of the following code?**
#     ```python
#     i = 1
#     while i < 4:
#         i += 1
#         if i == 3:
#             continue
#         print(i)
#     ```
#     - a) `2 3`
#     - b) `2 4`
#     - c) `1 2 3`
#     - d) `4`
#
# 12. **Which of the following is not a loop control statement in Python?**
#     - a) `break`
#     - b) `continue`
#     - c) `pass`
#     - d) `return`
#
# 13. **What will be the output of the following code?**
#     ```python
#     for i in range(3):
#         for j in range(2):
#             if i == j:
#                 break
#             print(i, j)
#     ```
#     - a) `0 0`

# %% [markdown]
# Here are 20 multiple-choice questions focusing on Python variables, data types, control structures, loops, and the `break` and `continue` statements:
#
# 1. **What is the correct syntax to declare a variable in Python?**
#    - a) `int x = 10`
#    - b) `x = 10`
#    - c) `declare x = 10`
#    - d) `x := 10`
#
# 2. **Which of the following is an immutable data type in Python?**
#    - a) `list`
#    - b) `dict`
#    - c) `set`
#    - d) `tuple`
#
# 3. **What will be the output of the following code?**
#    ```python
#    x = 5
#    if x > 2:
#        print("Greater")
#    else:
#        print("Lesser")
#    ```
#    - a) `Greater`
#    - b) `Lesser`
#    - c) `Error`
#    - d) No output
#
# 4. **Which loop is guaranteed to execute at least once?**
#    - a) `for` loop
#    - b) `while` loop
#    - c) `do-while` loop
#    - d) None of the above
#
# 5. **What is the purpose of the `break` statement in loops?**
#    - a) To skip the current iteration
#    - b) To exit the loop immediately
#    - c) To pause the loop
#    - d) To restart the loop
#
# 6. **What will be the output of the following code?**
#    ```python
#    for i in range(5):
#        if i == 3:
#            break
#        print(i)
#    ```
#    - a) `0 1 2 3 4`
#    - b) `0 1 2`
#    - c) `1 2 3`
#    - d) `0 1 2 3`
#
# 7. **What does the `continue` statement do in a loop?**
#    - a) Exits the loop
#    - b) Skips the rest of the code inside the loop for the current iteration
#    - c) Pauses the loop
#    - d) Restarts the loop
#
# 8. **Which of the following is a mutable data type in Python?**
#    - a) `str`
#    - b) `tuple`
#    - c) `list`
#    - d) `frozenset`
#
# 9. **What will be the output of the following code?**
#    ```python
#    x = 10
#    while x > 0:
#        x -= 2
#    print(x)
#    ```
#    - a) `10`
#    - b) `8`
#    - c) `0`
#    - d) `-2`
#
# 10. **How do you define a function in Python?**
#     - a) `function myFunc():`
#     - b) `def myFunc():`
#     - c) `define myFunc():`
#     - d) `func myFunc():`
#
# 11. **What is the output of the following code?**
#     ```python
#     for i in range(3):
#         for j in range(2):
#             if i == j:
#                 continue
#             print(i, j)
#     ```
#     - a) `0 0`
#     - b) `1 1`
#     - c) `2 2`
#     - d) `0 1`
#          `1 0`
#          `2 0`
#          `2 1`
#
# 12. **Which of the following is not a valid variable name in Python?**
#     - a) `_var`
#     - b) `var1`
#     - c) `1var`
#     - d) `var_1`
#
# 13. **What will be the output of the following code?**
#     ```python
#     x = [1, 2, 3]
#     y = x
#     y.append(4)
#     print(x)
#     ```
#     - a)
