# %% [markdown]
# Here is a **30-question Python quiz** covering concepts from **variables to dictionaries**.
#
# ---
#
# ### **Python Quiz: Variables to Dictionary**
#
# #### **Variables**
# 1. **How do you define a variable in Python?**
#    a) `var x = 10`
#    b) `x = 10`
#    c) `int x = 10`
#    d) `x := 10`
#
# 2. **Which of the following can a Python variable name start with?**
#    a) A number
#    b) A special character
#    c) A letter (A-Z, a-z) or underscore `_`
#    d) All of the above
#
# 3. **Which is the correct way to assign multiple variables in one line?**
#    a) `x = 10, y = 20, z = 30`
#    b) `x, y, z = 10, 20, 30`
#    c) `x = y = z = 10, 20, 30`
#    d) `x == 10, y == 20, z == 30`
#
# 4. **What will be the output of the following code?**
#    ```python
#    x = 5
#    y = x
#    x = 10
#    print(y)
#    ```
#    a) 5
#    b) 10
#    c) Error
#    d) None
#
# ---
#
# #### **Data Types**
# 5. **What is the output of `type(10)`?**
#    a) `int`
#    b) `float`
#    c) `double`
#    d) `long`
#
# 6. **Which of the following is NOT a valid data type in Python?**
#    a) `int`
#    b) `string`
#    c) `char`
#    d) `bool`
#
# 7. **What is the output of `print(type(3.14))`?**
#    a) `int`
#    b) `float`
#    c) `double`
#    d) `decimal`
#
# 8. **Which function is used to get user input in Python?**
#    a) `scan()`
#    b) `read()`
#    c) `input()`
#    d) `get()`
#
# ---
#
# #### **Lists**
# 9. **Which of the following defines a list in Python?**
#    a) `{1, 2, 3, 4}`
#    b) `[1, 2, 3, 4]`
#    c) `(1, 2, 3, 4)`
#    d) `None of the above`
#
# 10. **What will be the output of `len([1, 2, 3, 4])`?**
#     a) 3
#     b) 4
#     c) 5
#     d) Error
#
# 11. **How do you access the first element of a list `nums = [10, 20, 30]`?**
#     a) `nums(0)`
#     b) `nums[0]`
#     c) `nums{0}`
#     d) `nums.0`
#
# 12. **Which method adds an element to the end of a list?**
#     a) `add()`
#     b) `append()`
#     c) `insert()`
#     d) `extend()`
#
# ---
#
# #### **Tuples**
# 13. **What is the difference between a list and a tuple?**
#     a) Tuples are mutable, lists are immutable
#     b) Lists are mutable, tuples are immutable
#     c) Both are immutable
#     d) Both are mutable
#
# 14. **How do you define a tuple in Python?**
#     a) `[1, 2, 3]`
#     b) `{1, 2, 3}`
#     c) `(1, 2, 3)`
#     d) `tuple[1, 2, 3]`
#
# 15. **How do you access the last element of a tuple `t = (5, 10, 15, 20)`?**
#     a) `t[-1]`
#     b) `t[4]`
#     c) `t[last]`
#     d) `t[len(t)]`
#
# ---
#
# #### **Sets**
# 16. **What is the main characteristic of a set in Python?**
#     a) It is ordered
#     b) It allows duplicate values
#     c) It does not allow duplicate values
#     d) It is index-based
#
# 17. **Which function is used to add an element to a set?**
#     a) `add()`
#     b) `append()`
#     c) `insert()`
#     d) `push()`
#
# 18. **How do you create an empty set in Python?**
#     a) `{}`
#     b) `set()`
#     c) `[]`
#     d) `()`
#
# ---
#
# #### **Dictionaries**
# 19. **Which of the following defines a dictionary in Python?**
#     a) `{1, 2, 3}`
#     b) `{ "name": "Alice", "age": 25 }`
#     c) `["name", "Alice", "age", 25]`
#     d) `( "name": "Alice", "age": 25 )`
#
# 20. **What is the output of `len({"a": 1, "b": 2, "c": 3})`?**
#     a) 2
#     b) 3
#     c) 4
#     d) Error
#
# 21. **How do you access the value associated with the key `"name"` in the dictionary `person = {"name": "John", "age": 30}`?**
#     a) `person.name`
#     b) `person["name"]`
#     c) `person["John"]`
#     d) `person(age)`
#
# 22. **Which method removes an item from a dictionary?**
#     a) `delete()`
#     b) `pop()`
#     c) `remove()`
#     d) `discard()`
#
# 23. **Which method returns all the keys of a dictionary?**
#     a) `keys()`
#     b) `values()`
#     c) `items()`
#     d) `get_keys()`
#
# 24. **Which method checks if a key exists in a dictionary?**
#     a) `exists()`
#     b) `has_key()`
#     c) `in`
#     d) `check()`
#
# ---
#
# #### **Miscellaneous Questions**
# 25. **What is the correct syntax to check the data type of a variable `x`?**
#     a) `typeof(x)`
#     b) `type(x)`
#     c) `x.type()`
#     d) `datatype(x)`
#
# 26. **Which function is used to convert a string `"123"` into an integer?**
#     a) `str(123)`
#     b) `int("123")`
#     c) `convert("123")`
#     d) `to_int("123")`
#
# 27. **Which function is used to convert a list into a tuple?**
#     a) `list_to_tuple()`
#     b) `convert()`
#     c) `tuple()`
#     d) `to_tuple()`
#
# 28. **How do you get the number of items in a set?**
#     a) `count(set)`
#     b) `size(set)`
#     c) `len(set)`
#     d) `total(set)`
#
# 29. **What will be the output of `list("Python")`?**
#     a) `["Python"]`
#     b) `['P', 'y', 't', 'h', 'o', 'n']`
#     c) `['Python', 'Python']`
#     d) `['P y t h o n']`
#
# 30. **What will be the output of `set("hello")`?**
#     a) `{"hello"}`
#     b) `{'h', 'e', 'l', 'o'}`
#     c) `['h', 'e', 'l', 'l', 'o']`
#     d) `Error`
#
# ---
#
# This quiz tests fundamental Python concepts from **variables to dictionaries**. Let me know if you need answers or explanations! 🚀
