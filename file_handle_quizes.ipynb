# %% [markdown]
# <a href="https://colab.research.google.com/github/arunaimlprojects/python_totorial/blob/main/file_handle_quizes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Here are 20 quiz questions covering **File Handling, Serialization, and Deserialization in Python**:
#
# ### **File Handling**
# 1. Which function is used to open a file in Python?
#    a) read()
#    b) write()
#    c) open()
#    d) close()
#
# 2. Which mode is used to open a file in **append** mode?
#    a) "r"
#    b) "w"
#    c) "a"
#    d) "x"
#
# 3. Which mode is used to open a file in **text mode**?
#    a) "b"
#    b) "t"
#    c) "rb"
#    d) "wb"
#
# 4. What does the **readline()** function do?
#    a) Reads the entire file
#    b) Reads a single line from the file
#    c) Reads all lines as a list
#    d) Closes the file
#
# 5. What happens if you try to open a non-existent file in **"r"** mode?
#    a) Creates a new file
#    b) Opens the file successfully
#    c) Throws a `FileNotFoundError`
#    d) Deletes the file
#
# 6. What is the correct way to **write** data to a file?
#    a) `file.write("Hello")`
#    b) `file.read("Hello")`
#    c) `file.append("Hello")`
#    d) `file.input("Hello")`
#
# 7. What will `file.seek(0)` do in a file?
#    a) Move the cursor to the beginning
#    b) Move the cursor to the end
#    c) Delete file contents
#    d) Close the file
#
# 8. Which method is used to read **all lines** of a file as a list?
#    a) `file.readline()`
#    b) `file.readlines()`
#    c) `file.readall()`
#    d) `file.read()`
#
# 9. What is the **default** mode when opening a file using `open("file.txt")`?
#    a) "r"
#    b) "w"
#    c) "a"
#    d) "rb"
#
# 10. What is the best way to **ensure** a file is properly closed after use?
#    a) `file.close()`
#    b) `with open("file.txt") as file:`
#    c) `file.read()`
#    d) `file.seek(0)`
#
# ---
#
# ### **Serialization & Deserialization**
# 11. What is serialization in Python?
#    a) Converting an object to a byte stream
#    b) Storing a file in memory
#    c) Reading data from a file
#    d) None of the above
#
# 12. Which Python module is commonly used for serialization?
#    a) json
#    b) pickle
#    c) csv
#    d) both a & b
#
# 13. What does the `pickle.dump()` function do?
#    a) Reads an object from a file
#    b) Writes a serialized object to a file
#    c) Deletes a file
#    d) Appends an object to a file
#
# 14. How do you **deserialize** an object using the `pickle` module?
#    a) `pickle.load(file)`
#    b) `pickle.read(file)`
#    c) `pickle.loads(file)`
#    d) `pickle.dumps(file)`
#
# 15. What is the main difference between `pickle` and `json` serialization?
#    a) JSON is human-readable, while pickle is not
#    b) Pickle works only for numbers
#    c) JSON can serialize any Python object
#    d) Pickle only works with strings
#
# 16. What is the **file mode** required to save a serialized object using `pickle`?
#    a) "r"
#    b) "w"
#    c) "wb"
#    d) "rb"
#
# 17. Which function is used to serialize an object into a JSON string?
#    a) `json.load()`
#    b) `json.dumps()`
#    c) `json.dump()`
#    d) `json.write()`
#
# 18. How do you **deserialize** a JSON string into a Python object?
#    a) `json.load(file)`
#    b) `json.loads(json_string)`
#    c) `json.read(json_string)`
#    d) `json.serialize(json_string)`
#
# 19. Which Python module is best for working with CSV files?
#    a) pickle
#    b) json
#    c) csv
#    d) os
#
# 20. How do you write data to a CSV file?
#    a) `csv.writer(file).writerow(["data"])`
#    b) `csv.dump(file, ["data"])`
#    c) `csv.save(file, ["data"])`
#    d) `csv.append(file, ["data"])`
#
# Let me know if you want answers or explanations! 🚀
